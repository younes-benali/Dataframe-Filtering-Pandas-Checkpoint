# %%
import pandas as pd

data = {'Name': ['John', 'Mary', 'Bob', 'Sarah', 'Tom', 'Lisa'], 'Department': ['IT', 'Marketing', 'Sales', 'IT', 'Finance', 'Marketing'], 'Age': [30, 40, 25, 35, 45, 28], 'Gender': ['Male', 'Female', 'Male', 'Female', 'Male', 'Female'], 'Salary': [50000, 60000, 45000, 55000, 70000, 55000], 'Experience': [3, 7, 2, 5, 10, 4]}

employee_df = pd.DataFrame(data)
employee_df
# Out:
#     Name Department  Age  Gender  Salary  Experience
# 0   John         IT   30    Male   50000           3
# 1   Mary  Marketing   40  Female   60000           7
# 2    Bob      Sales   25    Male   45000           2
# 3  Sarah         IT   35  Female   55000           5
# 4    Tom    Finance   45    Male   70000          10
# 5   Lisa  Marketing   28  Female   55000           4

# %%
#Selecting 3 first columns with iloc
employee_df.iloc[:3]
# Out:
#    Name Department  Age  Gender  Salary  Experience
# 0  John         IT   30    Male   50000           3
# 1  Mary  Marketing   40  Female   60000           7
# 2   Bob      Sales   25    Male   45000           2

# %%
#loc method to select all rows where the Department is "Marketing : 
employee_df.loc[employee_df['Department'] =='Marketing']
# Out:
#    Name Department  Age  Gender  Salary  Experience
# 1  Mary  Marketing   40  Female   60000           7
# 5  Lisa  Marketing   28  Female   55000           4

# %%
# iloc method to select the Age and Gender columns for the first 4 rows of the dataframe
employee_df.iloc[:4][['Gender' ,'Age']]
# Out:
#    Gender  Age
# 0    Male   30
# 1  Female   40
# 2    Male   25
# 3  Female   35

# %%
# loc method to select the Salary and Experience columns for all rows where the Gender is "Male".
employee_df.loc[employee_df['Gender'] == 'Male'][["Gender","Experience","Salary"]]
# Out:
#   Gender  Experience  Salary
# 0   Male           3   50000
# 2   Male           2   45000
# 4   Male          10   70000
